# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Imen KADRI**
# Datascientist

# %% [markdown]
# *I am interested in data science because its the job that deals with data.*

# %% [markdown]
# ### The code below make addition of two numbers

# %%
a=3+2
print(a)
# Out:
# 5

# %% [markdown]
# step1...
#
# ---
# step2...
#
# ---
# step3...
#
# ---
